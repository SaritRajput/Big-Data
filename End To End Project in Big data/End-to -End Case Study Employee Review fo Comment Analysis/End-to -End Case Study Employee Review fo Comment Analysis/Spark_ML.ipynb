# %%
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql.functions import col, year, to_date, greatest, count, max
from pyspark.sql import Window
from pyspark.sql.functions import sum, when
from pyspark.sql import SparkSession
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder,OneHotEncoderModel, StringIndexer, VectorAssembler

# %%
spark = SparkSession.builder.appName("E2E_Capstone").config(
    "spark.ui.port", "0").config(
        "spark.sql.catalogImplementation=hive").config(
        "spark.sql.warehouse.dir",
        "hdfs://nameservice1/user/itv003722/warehouse/comment_analysis.db/review").config(
            "spark.serializer",
    "org.apache.spark.serializer.KryoSerializer").enableHiveSupport().getOrCreate()
spark.sparkContext.setLogLevel('OFF')

# %%
# Creating Local Views and Spark Dataframes to call these objects from memory.

review = spark.table('comment_analysis.review')
review.createOrReplaceTempView('review')

# %%
review.show()
review.printSchema()
review.count()
# Out:
# +-----+---------+-------------------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+
# |index|  company|              state| year|           job_title|             summary|                pros|                cons|overall_ratings|work_balance_stars|culture_values_stars|carrer_opportunities_stars|comp_benefit_stars|senior_mangemnet_stars|country|
# +-----+---------+-------------------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+
# |66367|microsoft|  Haidian; Beijing | 2013|Former Employee -...|It is a great jou...|Great working env...|Internal politics...|              4|                 3|                   3|                         3|                 4|                     4|  China|
# |66302|microsoft|  Beijing; Beijing | 2013|Current Employee ...|Good as a Project...|Comfortable as a ...|Too big for a Pro...|              5|                 5|                   5|                         5|                 5|                     5|  China|
# |66274|microsoft|Shanghai; Shanghai | 2013|Former Employee -...|              SDE II|good benefits & t...|it's just too big...|              4|                 4|                   4|                         4|                 4|                     5|  China|
# |66268|microsoft|Changping; Beijing | 2013|Current Employee ...|My work experienc...|Work Environment ...|Policy constraint...|              5|                 5|                   4|                         3|                 3|                     3|  China|
# |66248|microsoft|  Beijing; Beijing | 2013|Current Employee ...| Working environment|Good working plac...|Food service need...|              4|                 4|                   4|                         4|                 3|                     3|  China|
# |66237|microsoft|Shanghai; Shanghai | 2013|Current Employee ...|Well management c...|It is a good plac...|to many re-org ev...|              5|                 3|                   3|                         3|                 3|                     3|  China|
# |66209|microsoft|  Beijing; Beijing | 2013|Current Employee ...|Great place for work|Smart people; Nic...|none so far; upda...|              5|                 5|                   5|                         5|                 5|                     5|  China|
# |66194|microsoft|  Beijing; Beijing | 2013|Current Employee ...|MS a place for yo...|1 rich internal r...|1 too many KPIs 2...|              4|                 5|                   4|                         4|                 3|                     3|  China|
# | 7230|   google|Shanghai; Shanghai | 2013|Current Employee ...|I have been worki...|good study place ...|hard work; huge w...|              4|                 4|                   3|                         4|                 4|                     3|  China|
# |66173|microsoft|  Beijing; Beijing | 2013|Former Employee -...|Career path as a ...|The work is chall...|Too much politick...|              3|                 4|                   3|                         3|                 4|                     2|  China|
# |66158|microsoft|  Beijing; Beijing | 2013|Former Employee -...|7-year worked for...|enjoy working wit...|The leadership is...|              4|                 4|                   3|                         3|                 4|                     2|  China|
# |66154|microsoft|  Beijing; Beijing | 2013|Current Employee ...|      Great company!|There is rule hel...|Too much OT...I m...|              4|                 1|                   4|                         4|                 4|                     3|  China|
# |66117|microsoft|  Beijing; Beijing | 2013|Former Employee -...|Microsoft Researc...|The people there ...|Maybe you should ...|              5|                 5|                   5|                         5|                 5|                     5|  China|
# |66095|microsoft|Shanghai; Shanghai | 2013|Former Employee -...|Excellent Experience|Great Work Opport...|Big company somet...|              4|                 4|                   5|                         5|                 4|                     4|  China|
# |66065|microsoft|  Beijing; Beijing | 2013|Former Employee -...|                good|it provides lots ...|it is somewhat di...|              3|                 2|                   3|                         3|                 3|                     2|  China|
# |66062|microsoft|  Beijing; Beijing | 2013|Former Employee -...|    Software Engieer|Big company; with...|Too hard. Not eas...|              4|                 5|                   5|                         4|                 4|                     4|  China|
# |48867|    apple|Shanghai; Shanghai | 2013|Former Employee -...|Apple Store speci...|It's a great comp...|Strictly private!...|              4|                 5|                   5|                         5|                 5|                     5|  China|
# |33345|   amazon|  Beijing; Beijing | 2013|Former Employee -...|It was an amazing...|              #NAME?|-- Too much to le...|              4|                 3|                   5|                         4|                 4|                     4|  China|
# |33379|   amazon|  Beijing; Beijing | 2013|Current Employee ...|              No bad|Good salary and f...|Poor work environ...|              4|                 4|                   4|                         4|                 4|                     4|  China|
# |65588|microsoft|  Beijing; Beijing | 2014|Former Employee -...|      nice but short|great enterprise ...|the salaries of C...|              3|                 4|                   4|                         4|                 3|                     4|  China|
# +-----+---------+-------------------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+
# only showing top 20 rows
#
# root
#  |-- index: integer (nullable = true)
#  |-- company: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- pros: string (nullable = true)
#  |-- cons: string (nullable = true)
#  |-- overall_ratings: integer (nullable = true)
#  |-- work_balance_stars: integer (nullable = true)
#  |-- culture_values_stars: integer (nullable = true)
#  |-- carrer_opportunities_stars: integer (nullable = true)
#  |-- comp_benefit_stars: integer (nullable = true)
#  |-- senior_mangemnet_stars: integer (nullable = true)
#  |-- country: string (nullable = true)
# 67529

# %%
dfp = review.toPandas()

# %%
conti_var_df = dfp.loc[:, (dfp.dtypes == 'float64') | (
    dfp.dtypes == 'int64') | (dfp.dtypes == 'int32')]
cat_var_df = dfp.loc[:, (dfp.dtypes == 'object')]

# %%
# ### Continous Variables
def fun_describe(_):
    '''
        Calculates different metrics of Numerical column
    '''
    # Records and missing values
    n_tot = _.shape[0]
    n_count = _.count()
    n_miss = _.isna().sum()
    n_miss_perc = n_miss / n_tot

    # IQR
    q_1 = _.quantile(0.25)
    q_3 = _.quantile(0.75)
    iqr = q_3 - q_1
    lc_iqr = q_1 - 1.5 * iqr
    uc_iqr = q_3 + 1.5 * iqr

    return pd.Series(data=[
        _.dtypes, n_tot, n_count, n_miss, n_miss_perc,
        _.nunique(),
        _.sum(),
        _.mean(),
        _.std(),
        _.var(), iqr, lc_iqr, uc_iqr,
        _.min(),
        _.max(),
        _.quantile(0.01),
        _.quantile(0.05),
        _.quantile(0.1),
        _.quantile(0.25),
        _.quantile(0.5),
        _.quantile(0.75),
        _.quantile(0.90),
        _.quantile(0.95),
        _.quantile(0.99)
    ],
        index=[
        'dtype', 'tot', 'n', 'nmiss', 'miss_perc',
        'cardinality', 'sum', 'mean', 'std', 'var', 'iqr',
        'lc_iqr', 'uc_iqr', 'min', 'max', 'p1', 'p5', 'p10',
        'p25', 'p50', 'p75', 'p90', 'p95', 'p99'
    ])


conti_var_df.apply(fun_describe).T.head(50)
# Out:
#                             dtype    tot      n nmiss miss_perc cardinality  \
# index                       int32  67529  67529     0         0       67529
# overall_ratings             int32  67529  67529     0         0           5
# work_balance_stars          int32  67529  67529     0         0           5
# culture_values_stars        int32  67529  67529     0         0           5
# carrer_opportunities_stars  int32  67529  67529     0         0           5
# comp_benefit_stars          int32  67529  67529     0         0           5
# senior_mangemnet_stars      int32  67529  67529     0         0           5
#
#                                    sum     mean       std          var  ...  \
# index                       2280116685    33765   19494.1  3.80019e+08  ...
# overall_ratings                 258371  3.82607   1.15499        1.334  ...
# work_balance_stars              224056  3.31792   1.23596       1.5276  ...
# culture_values_stars            258480  3.82769   1.16215       1.3506  ...
# carrer_opportunities_stars      247193  3.66055   1.17084      1.37086  ...
# comp_benefit_stars              265402  3.93019  0.990349     0.980792  ...
# senior_mangemnet_stars          221256  3.27646   1.24128      1.54078  ...
#
#                               max      p1      p5     p10    p25    p50  \
# index                       67529  676.28  3377.4  6753.8  16883  33765
# overall_ratings                 5       1       1       2      3      4
# work_balance_stars              5       1       1       1      3      3
# culture_values_stars            5       1       1       2      3      4
# carrer_opportunities_stars      5       1       1       2      3      4
# comp_benefit_stars              5       1       2       3      3      4
# senior_mangemnet_stars          5       1       1       1      3      3
#
#                               p75      p90      p95      p99
# index                       50647  60776.2  64152.6  66853.7
# overall_ratings                 5        5        5        5
# work_balance_stars              4        5        5        5
# culture_values_stars            5        5        5        5
# carrer_opportunities_stars      5        5        5        5
# comp_benefit_stars              5        5        5        5
# senior_mangemnet_stars          4        5        5        5
#
# [7 rows x 24 columns]

# %%
# ### Categorical Variables
def fun_obj_describe(_):
    '''
        Calculates different metrics of Categorical column
    '''
    # Records and missing values
    n_tot = _.shape[0]
    n_count = _.count()
    n_miss = _.isna().sum()
    n_miss_perc = n_miss / n_tot

    return pd.Series(data=[
        _.dtypes, n_tot, n_count, n_miss, n_miss_perc,
        _.nunique()
    ],
        index=[
        'dtype', 'tot', 'n', 'nmiss', 'miss_perc',
        'cardinality'
    ])


cat_var_df.apply(fun_obj_describe).T.head(50)
# Out:
#             dtype    tot      n nmiss miss_perc cardinality
# company    object  67529  67529     0         0           6
# state      object  67529  67529     0         0         699
# year       object  67529  67529     0         0          13
# job_title  object  67529  67529     0         0        8308
# summary    object  67529  67529     0         0       42651
# pros       object  67529  67529     0         0       63789
# cons       object  67529  67529     0         0       64325
# country    object  67529  67529     0         0         106

# %%
df2=review.withColumn('Satisfied',\
                  F.when(review.overall_ratings>3,1)\
                  .otherwise(0)
                 ).show(5)
# Out:
# +-----+---------+----------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+---------+
# |index|  company|     state| year|           job_title|             summary|                pros|                cons|overall_ratings|work_balance_stars|culture_values_stars|carrer_opportunities_stars|comp_benefit_stars|senior_mangemnet_stars|country|Satisfied|
# +-----+---------+----------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+---------+
# |66420|microsoft|Bengaluru | 2013|Current Employee ...|Software Developm...|working with best...|Sometimes the pro...|              4|                 3|                   4|                         4|                 4|                     3|  India|        1|
# |66398|microsoft|Hyderabad | 2013|Former Employee -...|     Good Experience|work-life balance...|less mentoring; n...|              4|                 4|                   4|                         4|                 4|                     2|  India|        1|
# |66392|microsoft|Hyderabad | 2013|Current Employee ...|A very nice workp...|One get to work w...|Compensation can ...|              5|                 5|                   5|                         4|                 4|                     4|  India|        1|
# |66387|microsoft|Hyderabad | 2013|Current Employee ...|Lamb under a Tige...|the best talent i...|This is not what ...|              3|                 3|                   3|                         2|                 3|                     2|  India|        0|
# |66379|microsoft|   Mumbai | 2013|Current Employee ...|Solution Sales Pr...|Quite an importan...|Lot of politics L...|              3|                 3|                   2|                         3|                 4|                     2|  India|        0|
# +-----+---------+----------+-----+--------------------+--------------------+--------------------+--------------------+---------------+------------------+--------------------+--------------------------+------------------+----------------------+-------+---------+
# only showing top 5 rows

# %%
from pyspark_dist_explore import hist
import matplotlib.pyplot as plt

# %%
review.hist('Satisfied')

# %%
# Encoding columns with high cardinality may effect the model, so all of
# these categorical cols with high cardinality will be dropped later.


# Dropping these following columns since these do not seem to have any effect
# in Employee Left Status :
# 'emp_title_id','birth_date','last_date','hire_date','emp_no',
# 'title_id','dept_no','first_name','last_name'

df = review.drop(
    'index',
    'summary',
    
    'pros',
    'cons',
    'work_balance_stars',
    'culture_values_stars',
    'carrer_opportunities_stars',
    'comp_benefit_stars',
    'senior_mangemnet_stars',
    
     
    
    )
df.toPandas().head(20)
# Out:
#       company          state   year  \
# 0   microsoft        Prague    2014
# 1      amazon  Karlovy Vary    2015
# 2   microsoft        Prague    2015
# 3   microsoft        Prague    2015
# 4      amazon        Prague    2015
# 5   microsoft        Prague    2015
# 6      amazon        Prague    2016
# 7   microsoft        Prague    2016
# 8   microsoft        Prague    2016
# 9   microsoft        Prague    2016
# 10     amazon        Prague    2017
# 11     amazon        Prague    2017
# 12     amazon        Prague    2017
# 13     amazon        Prague    2017
# 14     amazon        Prague    2017
# 15     amazon        Prague    2017
# 16     amazon        Prague    2017
# 17     amazon        Prague    2017
# 18     amazon        Prague    2017
# 19     amazon        Prague    2017
#
#                                             job_title  overall_ratings  \
# 0                        Current Employee - Sales Job                2
# 1   Former Employee - English As A Second Language...                1
# 2      Former Employee - Inside Sales Account Manager                5
# 3                Former Employee - Anonymous Employee                4
# 4                      Current Employee - IT Engineer                4
# 5       Current Employee - Talent Acquisition Manager                4
# 6                     Current Employee - Area Manager                4
# 7   Current Employee - Global Human Resources Oper...                5
# 8                   Former Employee - Sales Executive                4
# 9                Former Employee - Anonymous Employee                5
# 10              Current Employee - Quality Specialist                5
# 11                    Former Employee - L4 Specialist                2
# 12   Current Employee - Human Resources Administrator                2
# 13     Current Employee - Human Resources Coordinator                5
# 14     Current Employee - Human Resources Coordinator                5
# 15                    Current Employee - Area Manager                2
# 16               Current Employee - HRS Administrator                5
# 17           Current Employee - IT Support Technician                3
# 18              Current Employee - Anonymous Employee                4
# 19   Current Employee - Human Resources Administrator                2
#
#            country
# 0   Czech Republic
# 1   Czech Republic
# 2   Czech Republic
# 3   Czech Republic
# 4   Czech Republic
# 5   Czech Republic
# 6   Czech Republic
# 7   Czech Republic
# 8   Czech Republic
# 9   Czech Republic
# 10  Czech Republic
# 11  Czech Republic
# 12  Czech Republic
# 13  Czech Republic
# 14  Czech Republic
# 15  Czech Republic
# 16  Czech Republic
# 17  Czech Republic
# 18  Czech Republic
# 19  Czech Republic

# %%
df.printSchema()
# Out:
# root
#  |-- company: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- overall_ratings: integer (nullable = true)
#  |-- country: string (nullable = true)

# %%
df.select('company').distinct().show()

# %%
##df.groupBy('company').agg(sum('overall_ratings'))

df.withColumn('Total yearly Sum', F.sum(
    'overall_ratings').over(Window.partitionBy('year'))).show()

# %%
result = df.groupBy("company").agg(sum(when(df.overall_ratings ==5, df.overall_ratings)).alias("sum_value"))
result.toPandas().head(20)

# %%
selected_data = df.groupBy("company","Year").agg(
    sum(when(df.overll_rating >= 3,1)).alias("satisfed"),
    sum(when(df.overll_rating <3,1)).alias("Not_satisfed")
).select("company","year" "satisfed", "satisfed")

# Show the selected columns
selected_data.toPandas().head(10)

# %%
review.satisfied(False,0.1).toPandas().hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ee2ae717485e> in <module>
# ----> 1 review.satisfied(False,0.1).toPandas().hist()
#
# /opt/spark-3.0.1-bin-hadoop3.2/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1399         if name not in self.columns:
#    1400             raise AttributeError(
# -> 1401                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1402         jc = self._jdf.apply(name)
#    1403         return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'satisfied'

# %%
df.select('year').distinct().show()

# %%
df.select('job_title').distinct().show()

# %%
df.na.drop(subset=["year"]) \
   .show(truncate=False)

# %%
df.select('year').distinct().show()

# %%
pandas_df = df.select("overall_ratings", "count").toPandas()

# Plot the bar chart using Pandas DataFrame and Matplotlib
pandas_df.plot(x="overall_ratings", y="count", kind="bar")
plt.xlabel("overall_ratings")
plt.ylabel("Count")
plt.title("Bar Chart")
plt.show()
